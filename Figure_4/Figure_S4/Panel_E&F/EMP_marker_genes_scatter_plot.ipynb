# %%
import scanpy as sc

# %%
adata_SS2_processed = sc.read_h5ad("SS2_processed.h5ad")
adata_MULTI_processed = sc.read_h5ad("MULTI_processed.h5ad")

# %%
sc.pl.scatter(adata_SS2_processed, x='E_score',y='M_score',color='VIM',size=20)
