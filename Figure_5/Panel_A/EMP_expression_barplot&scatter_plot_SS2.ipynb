# %%
import scanpy as sc
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
adata_SS2_processed = sc.read_h5ad('SS2_processed.h5ad')

# %%
adata_SS2_processed.X = adata_SS2_processed.layers['log1p']

# %%
SS2_log_counts_df = adata_SS2_processed.to_df()

# %%
for i in SS2_log_counts_df.index:
    SS2_log_counts_df.loc[i, 'EMP_score'] = adata_SS2_processed.obs.loc[i, 'EMP_score']
    SS2_log_counts_df.loc[i, 'EMP_stage'] = adata_SS2_processed.obs.loc[i, 'EMP_stage']

# %%
SS2_log_counts_df
# Out:
#                                                       TSPAN6  TNMD      DPM1  \
# A10_D088223_B106234_S10.homo.gencode.v30.ERCC.chrM  0.829182   0.0  0.000000
# A10_D088224_B106233_S10.homo.gencode.v30.ERCC.chrM  0.975753   0.0  1.110101
# A11_B008880_B106232_S11.homo.gencode.v30.ERCC.chrM  0.000000   0.0  2.060408
# A11_D088219_B106235_S11.homo.gencode.v30.ERCC.chrM  0.424829   0.0  0.416246
# A11_D088224_B106233_S11.homo.gencode.v30.ERCC.chrM  1.352078   0.0  0.032590
# ...                                                      ...   ...       ...
# P7_B008649_B008703.homo.gencode.v30.ERCC.chrM       0.000000   0.0  0.824991
# P8_B008649_B008703.homo.gencode.v30.ERCC.chrM       0.000000   0.0  0.000000
# P9_B008637_B008704.homo.gencode.v30.ERCC.chrM       0.000000   0.0  0.000000
# P9_B008648_B008695.homo.gencode.v30.ERCC.chrM       0.000000   0.0  0.000000
# P9_B008649_B008703.homo.gencode.v30.ERCC.chrM       0.000000   0.0  0.247510
#
# ...

# %%
overlap_H_genes = ['CRYAB', 'KRT15', 'S100A2', 'CD24', "CALML5"]

# %% [markdown]
# # making scatter plots

# %%
# for SS2

for i in overlap_H_genes:
    if i in SS2_log_counts_df.columns:
        SS2_log_counts_df_filtered = SS2_log_counts_df[SS2_log_counts_df[i] > 0]
        f, ax = plt.subplots(figsize=(2,2)) 
        sns.regplot(x='EMP_score', y=i, data=SS2_log_counts_df_filtered,ax=ax,order=2,scatter=False,color='black', ci=None)
        sns.scatterplot(x='EMP_score', y=i, data=SS2_log_counts_df, alpha=0.5, legend='full',ax=ax,hue='EMP_stage',hue_order = ['Epithelial-like', 'EMP Intermediate', 'Mesenchymal-like'],
               palette=['#81B1D3','#BC80B7','#F47F72'],s=5,edgecolor=None)
        ax.set_title('gene: '+i)
        ax.set_xlim(-1.2,1.2)
        ax.set_ylim(-0.1,)
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        plt.savefig('SS2_scatter_'+i+'_ref.pdf', bbox_inches="tight")
        plt.show()
        
        f, ax = plt.subplots(figsize=(2,2)) 
        sns.regplot(x='EMP_score', y=i, data=SS2_log_counts_df_filtered,ax=ax,order=2,scatter=False,color='black', ci=None)
        sns.scatterplot(x='EMP_score', y=i, data=SS2_log_counts_df, alpha=0.5, legend='full',ax=ax,hue='EMP_stage',hue_order = ['Epithelial-like', 'EMP Intermediate', 'Mesenchymal-like'],
               palette=['#81B1D3','#BC80B7','#F47F72'],s=5,edgecolor=None)
        ax.set_xlim(-1.2,1.2)
        ax.set_ylim(-0.1,)
        plt.legend([],[],frameon=False)
        ax.set(xlabel=None,ylabel=None,xticklabels=[],yticklabels=[])
        plt.savefig('SS2_scatter_'+i+'.pdf', bbox_inches="tight")
        plt.show()
        print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # making bar plots

# %%
# for SS2

for i in overlap_H_genes:
    if i in SS2_log_counts_df.columns:
        temp_df = pd.DataFrame(index=set(SS2_log_counts_df['EMP_stage']),columns=['fraction'])
        for j in set(SS2_log_counts_df['EMP_stage']):
            temp_EMT = SS2_log_counts_df[SS2_log_counts_df['EMP_stage']==j]
            temp_EMT_filtered = temp_EMT[temp_EMT[i] > 0]
            temp_df.loc[j, 'fraction'] = len(temp_EMT_filtered)/len(temp_EMT)
            temp_df['EMP_stage'] = temp_df.index
        f, ax = plt.subplots(figsize=(2,0.5))
        sns.barplot(x="EMP_stage", y="fraction", data=temp_df,order = ['Epithelial-like', 'EMP Intermediate', 'Mesenchymal-like'],
               palette=['#81B1D3','#BC80B7','#F47F72'])
        ax.set_ylim(0,1)
        plt.yticks([0, 0.5, 1])
        ax.set_title('gene: '+i)
        ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
        plt.savefig('SS2_bar_plots_'+i+'_ref.pdf', bbox_inches="tight")
        plt.show()
        
        
        f, ax = plt.subplots(figsize=(2,0.5))
        sns.barplot(x="EMP_stage", y="fraction", data=temp_df,order = ['Epithelial-like', 'EMP Intermediate', 'Mesenchymal-like'],
               palette=['#81B1D3','#BC80B7','#F47F72'])
        ax.set_ylim(0,1)
        plt.yticks([0, 0.5, 1])
        ax.axes.xaxis.set_visible(False)
        plt.legend([],[],frameon=False)
        ax.set(xlabel=None,ylabel=None,xticklabels=[],yticklabels=[])
        plt.savefig('SS2_bar_plots_'+i+'.pdf', bbox_inches="tight")
        plt.show()
        print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
